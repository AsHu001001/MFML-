# %%
import numpy as np
def chol(A):
 A=np.array(A,float)
 n=A.shape[0]
 L=np.zeros_like(A)
 for i in range(n):S
  for j in range(i+1):
   s=0
   for k in range(j):
    s=s+L[i,k]*L[j,k]
   if i==j:
    L[i,j]=(A[i,i]-s)**0.5
   else:
    L[i,j]=(A[i,j]-s)/L[j,j]
 return L

if __name__=="__main__":
 print(chol([[4,2],[2,3]]))
# Out:
# [[2.         0.        ]
#  [1.         1.41421356]]
